# %%
import pandas as pd
import warnings
warnings.simplefilter('ignore')

# %%
df=pd.read_csv('Employee.csv')
df
# Out:
#        Education  JoiningYear       City  PaymentTier  Age  Gender  \
# 0      Bachelors         2017       Pune            2   26    Male
# 1      Bachelors         2012  Bangalore            1   28  Female
# 2      Bachelors         2014  Bangalore            3   25  Female
# 3      Bachelors         2012  Bangalore            3   41    Male
# 4      Bachelors         2012  Bangalore            3   29  Female
# ...          ...          ...        ...          ...  ...     ...
# 44995    Masters         2015       Pune            2   33  Female
# 44996  Bachelors         2014  Bangalore            3   25    Male
# 44997  Bachelors         2013  Bangalore            3   28    Male
# 44998  Bachelors         2013  Bangalore            3   37  Female
# 44999  Bachelors         2014  Bangalore            1   34  Female
#
#       EverBenched  ExperienceInCurrentDomain  LeaveOrNot  EmployeeID
# 0              No                          4           0        1993
# 1              No                          3           0         121
# 2              No                          3           0        1017
# 3              No                          3           0        3056
# 4              No                          1           0        2440
# ...           ...                        ...         ...         ...
# 44995          No                          2           1        4072
# 44996          No                          3           0        1614
# 44997         Yes                          1           0        2170
# 44998          No                          2           1        4501
# 44999          No                          5           0        3678
#
# [45000 rows x 10 columns]

# %%
df.shape
# Out:
# (45000, 10)

# %%
df.nunique()
# Out:
# Education                       3
# JoiningYear                     7
# City                            3
# PaymentTier                     3
# Age                            20
# Gender                          2
# EverBenched                     2
# ExperienceInCurrentDomain       8
# LeaveOrNot                      2
# EmployeeID                   4653
# dtype: int64

# %%
df["EverBenched"].value_counts()
# Out:
# EverBenched
# No     40338
# Yes     4662
# Name: count, dtype: int64

# %%
df["EverBenched"].nunique()
# Out:
# 2

# %%
df.isna().sum()
# Out:
# Education                    0
# JoiningYear                  0
# City                         0
# PaymentTier                  0
# Age                          0
# Gender                       0
# EverBenched                  0
# ExperienceInCurrentDomain    0
# LeaveOrNot                   0
# EmployeeID                   0
# dtype: int64

# %%
df=df.drop_duplicates()

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 4653 entries, 0 to 33237
# Data columns (total 10 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Education                  4653 non-null   object
#  1   JoiningYear                4653 non-null   int64
#  2   City                       4653 non-null   object
#  3   PaymentTier                4653 non-null   int64
#  4   Age                        4653 non-null   int64
#  5   Gender                     4653 non-null   object
#  6   EverBenched                4653 non-null   object
#  7   ExperienceInCurrentDomain  4653 non-null   int64
#  8   LeaveOrNot                 4653 non-null   int64
#  9   EmployeeID                 4653 non-null   int64
# dtypes: int64(6), object(4)
# memory usage: 399.9+ KB

# %%
df.dtypes
# Out:
# Education                    object
# JoiningYear                   int64
# City                         object
# PaymentTier                   int64
# Age                           int64
# Gender                       object
# EverBenched                  object
# ExperienceInCurrentDomain     int64
# LeaveOrNot                    int64
# EmployeeID                    int64
# dtype: object

# %%
df.isna().sum()/df.shape[0]*100
# Out:
# Education                    0.0
# JoiningYear                  0.0
# City                         0.0
# PaymentTier                  0.0
# Age                          0.0
# Gender                       0.0
# EverBenched                  0.0
# ExperienceInCurrentDomain    0.0
# LeaveOrNot                   0.0
# EmployeeID                   0.0
# dtype: float64

# %%
df.head()
# Out:
#    Education  JoiningYear       City  PaymentTier  Age  Gender EverBenched  \
# 0  Bachelors         2017       Pune            2   26    Male          No
# 1  Bachelors         2012  Bangalore            1   28  Female          No
# 2  Bachelors         2014  Bangalore            3   25  Female          No
# 3  Bachelors         2012  Bangalore            3   41    Male          No
# 4  Bachelors         2012  Bangalore            3   29  Female          No
#
#    ExperienceInCurrentDomain  LeaveOrNot  EmployeeID
# 0                          4           0        1993
# 1                          3           0         121
# 2                          3           0        1017
# 3                          3           0        3056
# 4                          1           0        2440

# %%
df.tail()
# Out:
#        Education  JoiningYear       City  PaymentTier  Age  Gender  \
# 30331    Masters         2017  New Delhi            2   28    Male
# 30847    Masters         2015  New Delhi            3   37    Male
# 32182    Masters         2017       Pune            2   37    Male
# 32293  Bachelors         2017  New Delhi            2   36  Female
# 33237    Masters         2015  New Delhi            3   28  Female
#
#       EverBenched  ExperienceInCurrentDomain  LeaveOrNot  EmployeeID
# 30331          No                          2           0         937
# 30847          No                          2           1        3155
# 32182          No                          2           0        3001
# 32293          No                          5           0        3122
# 33237          No                          2           0        1627

# %%
df.columns
# Out:
# Index(['Education', 'JoiningYear', 'City', 'PaymentTier', 'Age', 'Gender',
#        'EverBenched', 'ExperienceInCurrentDomain', 'LeaveOrNot', 'EmployeeID'],
#       dtype='object')

# %%
df.describe().T
# Out:
#                             count         mean          std     min     25%  \
# JoiningYear                4653.0  2015.062970     1.863377  2012.0  2013.0
# PaymentTier                4653.0     2.698259     0.561435     1.0     3.0
# Age                        4653.0    29.393295     4.826087    22.0    26.0
# ExperienceInCurrentDomain  4653.0     2.905652     1.558240     0.0     2.0
# LeaveOrNot                 4653.0     0.343864     0.475047     0.0     0.0
# EmployeeID                 4653.0  2327.000000  1343.349731     1.0  1164.0
#
#                               50%     75%     max
# JoiningYear                2015.0  2017.0  2018.0
# PaymentTier                   3.0     3.0     3.0
# Age                          28.0    32.0    41.0
# ExperienceInCurrentDomain     3.0     4.0     7.0
# LeaveOrNot                    0.0     1.0     1.0
# EmployeeID                 2327.0  3490.0  4653.0

# %% [markdown]
# # EDA

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
sns.countplot(data=df,x='City')
plt.show()

# %%
sns.pairplot(df)

# %%
# HISTPLOT
df.hist(figsize=(20, 15), bins=26)
plt.suptitle("Feature Distribution", fontsize=20)
plt.show()

# %%
sns.boxplot(df)
plt.xticks(rotation=89.5)
plt.show()

# %%
col = "PaymentTier"
Q1 = df[col].quantile(0.25)
Q3 = df[col].quantile(0.75)
IQR = Q3 - Q1

lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

df_cleaned = df[(df[col] >= lower_bound) & (df[col] <= upper_bound)]

# %%
plt.figure(figsize=(12,6))
sns.boxplot(data=df_cleaned)
plt.xticks(rotation=45)
plt.show()

# %%
plt.figure(figsize=(19,10))
sns.heatmap(df.corr(numeric_only=True), annot=True, cmap='Dark2')
plt.title("Correlation Heatmap")
plt.show()

# %% [markdown]
# # PREPROCESSING

# %%
df
# Out:
#        Education  JoiningYear       City  PaymentTier  Age  Gender  \
# 0      Bachelors         2017       Pune            2   26    Male
# 1      Bachelors         2012  Bangalore            1   28  Female
# 2      Bachelors         2014  Bangalore            3   25  Female
# 3      Bachelors         2012  Bangalore            3   41    Male
# 4      Bachelors         2012  Bangalore            3   29  Female
# ...          ...          ...        ...          ...  ...     ...
# 30331    Masters         2017  New Delhi            2   28    Male
# 30847    Masters         2015  New Delhi            3   37    Male
# 32182    Masters         2017       Pune            2   37    Male
# 32293  Bachelors         2017  New Delhi            2   36  Female
# 33237    Masters         2015  New Delhi            3   28  Female
#
#       EverBenched  ExperienceInCurrentDomain  LeaveOrNot  EmployeeID
# 0              No                          4           0        1993
# 1              No                          3           0         121
# 2              No                          3           0        1017
# 3              No                          3           0        3056
# 4              No                          1           0        2440
# ...           ...                        ...         ...         ...
# 30331          No                          2           0         937
# 30847          No                          2           1        3155
# 32182          No                          2           0        3001
# 32293          No                          5           0        3122
# 33237          No                          2           0        1627
#
# [4653 rows x 10 columns]

# %%
from sklearn.preprocessing import LabelEncoder,StandardScaler

# %%
le=LabelEncoder()
df['Gender'] = le.fit_transform(df['Gender'])

# %%
le1=LabelEncoder()
df['Education'] = le1.fit_transform(df['Education'])

# %%
le2=LabelEncoder()
df['City'] = le2.fit_transform(df['City'])

# %%
le3=LabelEncoder()
df['EverBenched'] = le3.fit_transform(df['EverBenched'])

# %%
df
# Out:
#        Education  JoiningYear  City  PaymentTier  Age  Gender  EverBenched  \
# 0              0         2017     2            2   26       1            0
# 1              0         2012     0            1   28       0            0
# 2              0         2014     0            3   25       0            0
# 3              0         2012     0            3   41       1            0
# 4              0         2012     0            3   29       0            0
# ...          ...          ...   ...          ...  ...     ...          ...
# 30331          1         2017     1            2   28       1            0
# 30847          1         2015     1            3   37       1            0
# 32182          1         2017     2            2   37       1            0
# 32293          0         2017     1            2   36       0            0
# 33237          1         2015     1            3   28       0            0
#
#        ExperienceInCurrentDomain  LeaveOrNot  EmployeeID
# 0                              4           0        1993
# 1                              3           0         121
# 2                              3           0        1017
# 3                              3           0        3056
# 4                              1           0        2440
# ...                          ...         ...         ...
# 30331                          2           0         937
# 30847                          2           1        3155
# 32182                          2           0        3001
# 32293                          5           0        3122
# 33237                          2           0        1627
#
# [4653 rows x 10 columns]

# %%
df=df.drop(['EmployeeID'],axis=1)
df
# Out:
#        Education  JoiningYear  City  PaymentTier  Age  Gender  EverBenched  \
# 0              0         2017     2            2   26       1            0
# 1              0         2012     0            1   28       0            0
# 2              0         2014     0            3   25       0            0
# 3              0         2012     0            3   41       1            0
# 4              0         2012     0            3   29       0            0
# ...          ...          ...   ...          ...  ...     ...          ...
# 30331          1         2017     1            2   28       1            0
# 30847          1         2015     1            3   37       1            0
# 32182          1         2017     2            2   37       1            0
# 32293          0         2017     1            2   36       0            0
# 33237          1         2015     1            3   28       0            0
#
#        ExperienceInCurrentDomain  LeaveOrNot
# 0                              4           0
# 1                              3           0
# 2                              3           0
# 3                              3           0
# 4                              1           0
# ...                          ...         ...
# 30331                          2           0
# 30847                          2           1
# 32182                          2           0
# 32293                          5           0
# 33237                          2           0
#
# [4653 rows x 9 columns]

# %%
x=df.drop('LeaveOrNot',axis=1)
y=df[['LeaveOrNot']]

# %%
x
# Out:
#        Education  JoiningYear  City  PaymentTier  Age  Gender  EverBenched  \
# 0              0         2017     2            2   26       1            0
# 1              0         2012     0            1   28       0            0
# 2              0         2014     0            3   25       0            0
# 3              0         2012     0            3   41       1            0
# 4              0         2012     0            3   29       0            0
# ...          ...          ...   ...          ...  ...     ...          ...
# 30331          1         2017     1            2   28       1            0
# 30847          1         2015     1            3   37       1            0
# 32182          1         2017     2            2   37       1            0
# 32293          0         2017     1            2   36       0            0
# 33237          1         2015     1            3   28       0            0
#
#        ExperienceInCurrentDomain
# 0                              4
# 1                              3
# 2                              3
# 3                              3
# 4                              1
# ...                          ...
# 30331                          2
# 30847                          2
# 32182                          2
# 32293                          5
# 33237                          2
#
# [4653 rows x 8 columns]

# %%
y
# Out:
#        LeaveOrNot
# 0               0
# 1               0
# 2               0
# 3               0
# 4               0
# ...           ...
# 30331           0
# 30847           1
# 32182           0
# 32293           0
# 33237           0
#
# [4653 rows x 1 columns]

# %% [markdown]
# # TRAIN TEST SPLIT

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.25,random_state=60)

# %%
x_train
# Out:
#       Education  JoiningYear  City  PaymentTier  Age  Gender  EverBenched  \
# 3550          0         2017     1            2   25       1            0
# 131           2         2015     1            2   27       0            0
# 1014          0         2017     0            3   34       1            0
# 917           0         2014     1            3   30       0            0
# 614           0         2017     0            3   32       1            0
# ...         ...          ...   ...          ...  ...     ...          ...
# 2885          0         2012     2            3   24       1            1
# 1696          2         2015     1            1   37       1            0
# 7231          0         2013     2            3   25       1            0
# 5217          1         2017     1            3   30       1            0
# 3089          1         2018     1            3   27       0            0
#
#       ExperienceInCurrentDomain
# 3550                          3
# 131                           5
# 1014                          3
# 917                           3
# 614                           4
# ...                         ...
# 2885                          2
# 1696                          1
# 7231                          3
# 5217                          3
# 3089                          5
#
# [3489 rows x 8 columns]

# %%
y_train
# Out:
#       LeaveOrNot
# 3550           0
# 131            0
# 1014           0
# 917            0
# 614            0
# ...          ...
# 2885           0
# 1696           0
# 7231           0
# 5217           1
# 3089           1
#
# [3489 rows x 1 columns]

# %% [markdown]
# # SCALING

# %%
scaler=StandardScaler()
x_train=scaler.fit_transform(x_train)
x_test=scaler.transform(x_test)

# %% [markdown]
# # LOGISTIC REGRESSION

# %%
from sklearn.metrics  import accuracy_score
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import classification_report,ConfusionMatrixDisplay

# %%
lr=LogisticRegression()
lr.fit(x_train,y_train)
y_testpred=lr.predict(x_test)
y_trainpred=lr.predict(x_train)
print('Test score:',lr.score(x_test,y_test))
print('train score:',lr.score(x_train,y_train))
print(ConfusionMatrixDisplay.from_predictions(y_test,y_testpred))
print('CR:',classification_report(y_test,y_testpred))
lrt=accuracy_score(y_test,y_testpred)*100
lrr=accuracy_score(y_train,y_trainpred)*100
print('Test accuracy:',lrt)
print('Train accuracy:',lrr)
# Out:
# Test score: 0.7027491408934707
# train score: 0.7036400114646031
# <sklearn.metrics._plot.confusion_matrix.ConfusionMatrixDisplay object at 0x0000017E28E401A0>
# CR:               precision    recall  f1-score   support
#
#            0       0.72      0.88      0.79       754
#            1       0.63      0.37      0.47       410
#
#     accuracy                           0.70      1164
#    macro avg       0.68      0.63      0.63      1164
# weighted avg       0.69      0.70      0.68      1164
#
# Test accuracy: 70.27491408934708
# Train accuracy: 70.36400114646031

# %% [markdown]
# # DECISION TREE

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
dt=DecisionTreeClassifier(criterion='entropy')
dt.fit(x_train,y_train)
y_testpred=dt.predict(x_test)
y_trainpred=dt.predict(x_train)
print('Test accuracy:',dt.score(x_test,y_test))
print('train accuracy:',dt.score(x_train,y_train))
print(ConfusionMatrixDisplay.from_predictions(y_test,y_testpred))
print('CR:',classification_report(y_test,y_testpred))
dtt=accuracy_score(y_test,y_testpred)*100
dtr=accuracy_score(y_train,y_trainpred)*100
print('Test accuracy:',dtt)
print('Train accuracy:',dtr)
# Out:
# Test accuracy: 0.8101374570446735
# train accuracy: 0.9323588420750931
# <sklearn.metrics._plot.confusion_matrix.ConfusionMatrixDisplay object at 0x0000017E299D7390>
# CR:               precision    recall  f1-score   support
#
#            0       0.82      0.90      0.86       754
#            1       0.78      0.64      0.70       410
#
#     accuracy                           0.81      1164
#    macro avg       0.80      0.77      0.78      1164
# weighted avg       0.81      0.81      0.81      1164
#
# Test accuracy: 81.01374570446735
# Train accuracy: 93.23588420750932

# %% [markdown]
# # RANDOM FOREST CLASSIFIER

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
rf=RandomForestClassifier(n_estimators=5,random_state=10)
rf.fit(x_train,y_train)
y_testpred=rf.predict(x_test)
y_trainpred=rf.predict(x_train)
print('Test accuracy:',rf.score(x_test,y_test))
print('train accuracy:',rf.score(x_train,y_train))
print(ConfusionMatrixDisplay.from_predictions(y_test,y_testpred))
print('CR:',classification_report(y_test,y_testpred))
rft=accuracy_score(y_test,y_testpred)*100
rfr=accuracy_score(y_train,y_trainpred)*100
print('Test accuracy:',rft)
print('Train accuracy:',rfr)
# Out:
# Test accuracy: 0.8058419243986255
# train accuracy: 0.9183147033533964
# <sklearn.metrics._plot.confusion_matrix.ConfusionMatrixDisplay object at 0x0000017E2B0F6210>
# CR:               precision    recall  f1-score   support
#
#            0       0.82      0.90      0.86       754
#            1       0.78      0.63      0.70       410
#
#     accuracy                           0.81      1164
#    macro avg       0.80      0.77      0.78      1164
# weighted avg       0.80      0.81      0.80      1164
#
# Test accuracy: 80.58419243986255
# Train accuracy: 91.83147033533963

# %% [markdown]
# # X-G BOOST

# %%
from xgboost import XGBClassifier

# %%
xgb = XGBClassifier()
xgb.fit(x_train, y_train)
y_testpred=xgb.predict(x_test)
y_trainpred=xgb.predict(x_train)
print('Test accuracy:',xgb.score(x_test,y_test))
print('train accuracy:',xgb.score(x_train,y_train))
print(ConfusionMatrixDisplay.from_predictions(y_test,y_testpred))
print('CR:',classification_report(y_test,y_testpred))
xgt=accuracy_score(y_test,y_testpred)*100
xgr=accuracy_score(y_train,y_trainpred)*100
print('Test accuracy:',xgt)
print('Train accuracy:',xgr)
# Out:
# Test accuracy: 0.8350515463917526
# train accuracy: 0.9065634852393236
# <sklearn.metrics._plot.confusion_matrix.ConfusionMatrixDisplay object at 0x0000017E2B0F35C0>
# CR:               precision    recall  f1-score   support
#
#            0       0.83      0.94      0.88       754
#            1       0.85      0.65      0.73       410
#
#     accuracy                           0.84      1164
#    macro avg       0.84      0.79      0.81      1164
# weighted avg       0.84      0.84      0.83      1164
#
# Test accuracy: 83.50515463917526
# Train accuracy: 90.65634852393237

# %% [markdown]
# # SVM

# %%
from sklearn.svm import SVC

# %%
sv=SVC()
sv.fit(x_train,y_train)
y_testpred=sv.predict(x_test)
y_trainpred=sv.predict(x_train)
print('Test score:',sv.score(x_test,y_test))
print('train score:',sv.score(x_train,y_train))
print(ConfusionMatrixDisplay.from_predictions(y_test,y_testpred))
print('CR:',classification_report(y_test,y_testpred))
svt=accuracy_score(y_test,y_testpred)*100
svr=accuracy_score(y_train,y_trainpred)*100
print('Test accuracy:',svt)
print('Train accuracy:',svr)
# Out:
# Test score: 0.8290378006872853
# train score: 0.8535396961880195
# <sklearn.metrics._plot.confusion_matrix.ConfusionMatrixDisplay object at 0x0000017E2B0F1810>
# CR:               precision    recall  f1-score   support
#
#            0       0.82      0.95      0.88       754
#            1       0.86      0.61      0.72       410
#
#     accuracy                           0.83      1164
#    macro avg       0.84      0.78      0.80      1164
# weighted avg       0.83      0.83      0.82      1164
#
# Test accuracy: 82.90378006872852
# Train accuracy: 85.35396961880195

# %% [markdown]
# # KNN

# %%
from sklearn.neighbors import KNeighborsClassifier

# %%
knn=KNeighborsClassifier(n_neighbors=3)
knn.fit(x_train,y_train)
y_testpred=knn.predict(x_test)
y_trainpred=knn.predict(x_train)
print('Test accuracy:',knn.score(x_test,y_test))
print('train accuracy:',knn.score(x_train,y_train))
print(ConfusionMatrixDisplay.from_predictions(y_test,y_testpred))
print('CR:',classification_report(y_test,y_testpred))
knnt=accuracy_score(y_test,y_testpred)*100
knnr=accuracy_score(y_train,y_trainpred)*100
print('Test accuracy:',knnt)
print('Train accuracy:',knnr)
# Out:
# Test accuracy: 0.8178694158075601
# train accuracy: 0.883061049011178
# <sklearn.metrics._plot.confusion_matrix.ConfusionMatrixDisplay object at 0x0000017E2A0DF890>
# CR:               precision    recall  f1-score   support
#
#            0       0.82      0.92      0.87       754
#            1       0.81      0.63      0.71       410
#
#     accuracy                           0.82      1164
#    macro avg       0.82      0.78      0.79      1164
# weighted avg       0.82      0.82      0.81      1164
#
# Test accuracy: 81.78694158075601
# Train accuracy: 88.3061049011178

# %% [markdown]
# # NAIVE BAYES

# %%
from sklearn.naive_bayes import GaussianNB

# %%
gb=GaussianNB()
gb.fit(x_train,y_train)
y_testpred=gb.predict(x_test)
y_trainpred=gb.predict(x_train)
print('Test accuracy:',gb.score(x_test,y_test))
print('train accuracy:',gb.score(x_train,y_train))
print(ConfusionMatrixDisplay.from_predictions(y_test,y_testpred))
print('CR:',classification_report(y_test,y_testpred))
gbt=accuracy_score(y_test,y_testpred)*100
gbr=accuracy_score(y_train,y_trainpred)*100
print('Test accuracy:',gbt)
print('Train accuracy:',gbr)
# Out:
# Test accuracy: 0.6838487972508591
# train accuracy: 0.6861564918314703
# <sklearn.metrics._plot.confusion_matrix.ConfusionMatrixDisplay object at 0x0000017E247D6BE0>
# CR:               precision    recall  f1-score   support
#
#            0       0.73      0.81      0.77       754
#            1       0.57      0.44      0.50       410
#
#     accuracy                           0.68      1164
#    macro avg       0.65      0.63      0.63      1164
# weighted avg       0.67      0.68      0.67      1164
#
# Test accuracy: 68.38487972508591
# Train accuracy: 68.61564918314703

# %% [markdown]
# # ADABOOST

# %%
from sklearn.ensemble import AdaBoostClassifier

# %%
adaboost=AdaBoostClassifier(n_estimators=10,estimator=None,learning_rate=0.2,random_state=5)
adaboost.fit(x_train,y_train)
y_testpred=adaboost.predict(x_test)
y_trainpred=adaboost.predict(x_train)
print('Test accuracy:',adaboost.score(x_test,y_test))
print('train accuracy:',adaboost.score(x_train,y_train))
print(ConfusionMatrixDisplay.from_predictions(y_test,y_testpred))
print('CR:',classification_report(y_test,y_testpred))
adt=accuracy_score(y_test,y_testpred)*100
adr=accuracy_score(y_train,y_trainpred)*100
print('Test accuracy:',adt)
print('Train accuracy:',adr)
# Out:
# Test accuracy: 0.7156357388316151
# train accuracy: 0.7386070507308684
# <sklearn.metrics._plot.confusion_matrix.ConfusionMatrixDisplay object at 0x0000017E2B112250>
# CR:               precision    recall  f1-score   support
#
#            0       0.69      1.00      0.82       754
#            1       1.00      0.19      0.32       410
#
#     accuracy                           0.72      1164
#    macro avg       0.85      0.60      0.57      1164
# weighted avg       0.80      0.72      0.64      1164
#
# Test accuracy: 71.56357388316151
# Train accuracy: 73.86070507308685

# %% [markdown]
# # GRADIENT BOOSTING

# %%
from sklearn.ensemble import GradientBoostingClassifier

# %%
gbc=GradientBoostingClassifier(n_estimators=100,learning_rate=0.05,random_state=200)
gbc.fit(x_train,y_train)
y_testpred=gbc.predict(x_test)
y_trainpred=gbc.predict(x_train)
print('Test accuracy:',gbc.score(x_test,y_test))
print('train accuracy:',gbc.score(x_train,y_train))
print(ConfusionMatrixDisplay.from_predictions(y_test,y_testpred))
print('CR:',classification_report(y_test,y_testpred))
gbt=accuracy_score(y_test,y_testpred)*100
gbr=accuracy_score(y_train,y_trainpred)*100
print('Test accuracy:',gbt)
print('Train accuracy:',gbr)
# Out:
# Test accuracy: 0.8058419243986255
# train accuracy: 0.8283175695041559
# <sklearn.metrics._plot.confusion_matrix.ConfusionMatrixDisplay object at 0x0000017E2B253B50>
# CR:               precision    recall  f1-score   support
#
#            0       0.79      0.96      0.86       754
#            1       0.87      0.53      0.66       410
#
#     accuracy                           0.81      1164
#    macro avg       0.83      0.74      0.76      1164
# weighted avg       0.82      0.81      0.79      1164
#
# Test accuracy: 80.58419243986255
# Train accuracy: 82.8317569504156

# %% [markdown]
# # INITIAL PERFORMANCE

# %%
tb=pd.DataFrame()
tb['model']=pd.Series(['knn','lr','gb','rf','adaboost','gbc','dt','xgb','sv'])
tb['test_accuracy']=pd.Series([knnt,lrt,gbt,rft,adt,gbt,dtt,xgt,svt])
tb['train_accuracy']=pd.Series([knnr,lrr,gbr,rfr,adr,gbr,dtr,xgr,svr])
tb
# Out:
#       model  test_accuracy  train_accuracy
# 0       knn      81.786942       88.306105
# 1        lr      70.274914       70.364001
# 2        gb      80.584192       82.831757
# 3        rf      80.584192       91.831470
# 4  adaboost      71.563574       73.860705
# 5       gbc      80.584192       82.831757
# 6        dt      81.013746       93.235884
# 7       xgb      83.505155       90.656349
# 8        sv      82.903780       85.353970

# %% [markdown]
# # BALANCING OF DATA

# %%
from imblearn.over_sampling import SMOTE
#from collections import Counter
# Apply SMOTE
smote = SMOTE(random_state=42)
x_resampled, y_resampled = smote.fit_resample(x,y)
y_resampled.value_counts()
# Out:
# LeaveOrNot
# 0             3053
# 1             3053
# Name: count, dtype: int64

# %% [markdown]
# # TRAIN TEST SPLIT AFTER SMOTE

# %%
x_train,x_test,y_train,y_test=train_test_split(x_resampled,y_resampled,test_size=0.25,random_state=60)

# %% [markdown]
# ### LOGISTIC REGRESSION

# %%
lr=LogisticRegression()
lr.fit(x_train,y_train)
y_testpred=lr.predict(x_test)
y_trainpred=lr.predict(x_train)
print('Test score:',lr.score(x_test,y_test))
print('train score:',lr.score(x_train,y_train))
print(ConfusionMatrixDisplay.from_predictions(y_test,y_testpred))
print('CR:',classification_report(y_test,y_testpred))
lrt=accuracy_score(y_test,y_testpred)*100
lrr=accuracy_score(y_train,y_trainpred)*100
print('Test accuracy:',lrt)
print('Train accuracy:',lrr)
# Out:
# Test score: 0.6326129666011788
# train score: 0.6499235640969644
# <sklearn.metrics._plot.confusion_matrix.ConfusionMatrixDisplay object at 0x0000017E2DAAC250>
# CR:               precision    recall  f1-score   support
#
#            0       0.62      0.69      0.65       757
#            1       0.65      0.58      0.61       770
#
#     accuracy                           0.63      1527
#    macro avg       0.63      0.63      0.63      1527
# weighted avg       0.63      0.63      0.63      1527
#
# Test accuracy: 63.261296660117885
# Train accuracy: 64.99235640969644

# %% [markdown]
# ### DECISION TREE

# %%
dt=DecisionTreeClassifier(criterion='entropy')
dt.fit(x_train,y_train)
y_testpred=dt.predict(x_test)
y_trainpred=dt.predict(x_train)
print('Test accuracy:',dt.score(x_test,y_test))
print('train accuracy:',dt.score(x_train,y_train))
print(ConfusionMatrixDisplay.from_predictions(y_test,y_testpred))
print('CR:',classification_report(y_test,y_testpred))
dtt=accuracy_score(y_test,y_testpred)*100
dtr=accuracy_score(y_train,y_trainpred)*100
print('Test accuracy:',dtt)
print('Train accuracy:',dtr)
# Out:
# Test accuracy: 0.8087753765553373
# train accuracy: 0.9181043896047172
# <sklearn.metrics._plot.confusion_matrix.ConfusionMatrixDisplay object at 0x0000017E2DAA45F0>
# CR:               precision    recall  f1-score   support
#
#            0       0.78      0.85      0.81       757
#            1       0.84      0.77      0.80       770
#
#     accuracy                           0.81      1527
#    macro avg       0.81      0.81      0.81      1527
# weighted avg       0.81      0.81      0.81      1527
#
# Test accuracy: 80.87753765553373
# Train accuracy: 91.81043896047171

# %% [markdown]
# ### RANDOM FOREST CLASSIFIER

# %%
rf=RandomForestClassifier(n_estimators=5,random_state=10)
rf.fit(x_train,y_train)
y_testpred=rf.predict(x_test)
y_trainpred=rf.predict(x_train)
print('Test accuracy:',rf.score(x_test,y_test))
print('train accuracy:',rf.score(x_train,y_train))
print(ConfusionMatrixDisplay.from_predictions(y_test,y_testpred))
print('CR:',classification_report(y_test,y_testpred))
rft=accuracy_score(y_test,y_testpred)*100
rfr=accuracy_score(y_train,y_trainpred)*100
print('Test accuracy:',rft)
print('Train accuracy:',rfr)
# Out:
# Test accuracy: 0.7969875573018992
# train accuracy: 0.9058746451190216
# <sklearn.metrics._plot.confusion_matrix.ConfusionMatrixDisplay object at 0x0000017E2DAA5F40>
# CR:               precision    recall  f1-score   support
#
#            0       0.77      0.83      0.80       757
#            1       0.82      0.76      0.79       770
#
#     accuracy                           0.80      1527
#    macro avg       0.80      0.80      0.80      1527
# weighted avg       0.80      0.80      0.80      1527
#
# Test accuracy: 79.69875573018992
# Train accuracy: 90.58746451190216

# %% [markdown]
# ### XG BOOST

# %%
xgb = XGBClassifier()
xgb.fit(x_train, y_train)
y_testpred=xgb.predict(x_test)
y_trainpred=xgb.predict(x_train)
print('Test accuracy:',xgb.score(x_test,y_test))
print('train accuracy:',xgb.score(x_train,y_train))
print(ConfusionMatrixDisplay.from_predictions(y_test,y_testpred))
print('CR:',classification_report(y_test,y_testpred))
xgt=accuracy_score(y_test,y_testpred)*100
xgr=accuracy_score(y_train,y_trainpred)*100
print('Test accuracy:',xgt)
print('Train accuracy:',xgr)
# Out:
# Test accuracy: 0.8120497707924034
# train accuracy: 0.8844725922690544
# <sklearn.metrics._plot.confusion_matrix.ConfusionMatrixDisplay object at 0x0000017E2DBB2190>
# CR:               precision    recall  f1-score   support
#
#            0       0.78      0.86      0.82       757
#            1       0.85      0.76      0.80       770
#
#     accuracy                           0.81      1527
#    macro avg       0.82      0.81      0.81      1527
# weighted avg       0.82      0.81      0.81      1527
#
# Test accuracy: 81.20497707924034
# Train accuracy: 88.44725922690544

# %% [markdown]
# ### SVM

# %%
sv=SVC()
sv.fit(x_train,y_train)
y_testpred=sv.predict(x_test)
y_trainpred=sv.predict(x_train)
print('Test score:',sv.score(x_test,y_test))
print('train score:',sv.score(x_train,y_train))
print(ConfusionMatrixDisplay.from_predictions(y_test,y_testpred))
print('CR:',classification_report(y_test,y_testpred))
svt=accuracy_score(y_test,y_testpred)*100
svr=accuracy_score(y_train,y_trainpred)*100
print('Test accuracy:',svt)
print('Train accuracy:',svr)
# Out:
# Test score: 0.495743287491814
# train score: 0.5014195239135182
# <sklearn.metrics._plot.confusion_matrix.ConfusionMatrixDisplay object at 0x0000017E2DBF6DD0>
# CR:               precision    recall  f1-score   support
#
#            0       0.50      1.00      0.66       757
#            1       0.00      0.00      0.00       770
#
#     accuracy                           0.50      1527
#    macro avg       0.25      0.50      0.33      1527
# weighted avg       0.25      0.50      0.33      1527
#
# Test accuracy: 49.574328749181404
# Train accuracy: 50.14195239135182

# %% [markdown]
# ### KNN

# %%
knn=KNeighborsClassifier(n_neighbors=3)
knn.fit(x_train,y_train)
y_testpred=knn.predict(x_test)
y_trainpred=knn.predict(x_train)
print('Test accuracy:',knn.score(x_test,y_test))
print('train accuracy:',knn.score(x_train,y_train))
print(ConfusionMatrixDisplay.from_predictions(y_test,y_testpred))
print('CR:',classification_report(y_test,y_testpred))
knnt=accuracy_score(y_test,y_testpred)*100
knnr=accuracy_score(y_train,y_trainpred)*100
print('Test accuracy:',knnt)
print('Train accuracy:',knnr)
# Out:
# Test accuracy: 0.7714472822527833
# train accuracy: 0.8628521511246997
# <sklearn.metrics._plot.confusion_matrix.ConfusionMatrixDisplay object at 0x0000017E2DADB860>
# CR:               precision    recall  f1-score   support
#
#            0       0.77      0.77      0.77       757
#            1       0.77      0.78      0.77       770
#
#     accuracy                           0.77      1527
#    macro avg       0.77      0.77      0.77      1527
# weighted avg       0.77      0.77      0.77      1527
#
# Test accuracy: 77.14472822527833
# Train accuracy: 86.28521511246997

# %% [markdown]
# ### NAIVE BAYES

# %%
gb=GaussianNB()
gb.fit(x_train,y_train)
y_testpred=gb.predict(x_test)
y_trainpred=gb.predict(x_train)
print('Test accuracy:',gb.score(x_test,y_test))
print('train accuracy:',gb.score(x_train,y_train))
print(ConfusionMatrixDisplay.from_predictions(y_test,y_testpred))
print('CR:',classification_report(y_test,y_testpred))
gbt=accuracy_score(y_test,y_testpred)*100
gbr=accuracy_score(y_train,y_trainpred)*100
print('Test accuracy:',gbt)
print('Train accuracy:',gbr)
# Out:
# Test accuracy: 0.6496398166339227
# train accuracy: 0.6759117711290675
# <sklearn.metrics._plot.confusion_matrix.ConfusionMatrixDisplay object at 0x0000017E2D7DFD10>
# CR:               precision    recall  f1-score   support
#
#            0       0.63      0.71      0.67       757
#            1       0.68      0.59      0.63       770
#
#     accuracy                           0.65      1527
#    macro avg       0.65      0.65      0.65      1527
# weighted avg       0.65      0.65      0.65      1527
#
# Test accuracy: 64.96398166339226
# Train accuracy: 67.59117711290675

# %% [markdown]
# # ENSEMBLE MODEL

# %% [markdown]
# ### ADABOOST

# %%
adaboost=AdaBoostClassifier(n_estimators=10,estimator=None,learning_rate=0.2,random_state=5)
adaboost.fit(x_train,y_train)
y_testpred=adaboost.predict(x_test)
y_trainpred=adaboost.predict(x_train)
print('Test accuracy:',adaboost.score(x_test,y_test))
print('train accuracy:',adaboost.score(x_train,y_train))
print(ConfusionMatrixDisplay.from_predictions(y_test,y_testpred))
print('CR:',classification_report(y_test,y_testpred))
adt=accuracy_score(y_test,y_testpred)*100
adr=accuracy_score(y_train,y_trainpred)*100
print('Test accuracy:',adt)
print('Train accuracy:',adr)
# Out:
# Test accuracy: 0.6077275703994761
# train accuracy: 0.609740117929679
# <sklearn.metrics._plot.confusion_matrix.ConfusionMatrixDisplay object at 0x0000017E2DC33B90>
# CR:               precision    recall  f1-score   support
#
#            0       0.56      1.00      0.72       757
#            1       1.00      0.22      0.36       770
#
#     accuracy                           0.61      1527
#    macro avg       0.78      0.61      0.54      1527
# weighted avg       0.78      0.61      0.54      1527
#
# Test accuracy: 60.772757039947614
# Train accuracy: 60.9740117929679

# %% [markdown]
# ### GRADIENT BOOSTING

# %%
gbc=GradientBoostingClassifier(n_estimators=100,learning_rate=0.05,random_state=200)
gbc.fit(x_train,y_train)
y_testpred=gbc.predict(x_test)
y_trainpred=gbc.predict(x_train)
print('Test accuracy:',gbc.score(x_test,y_test))
print('train accuracy:',gbc.score(x_train,y_train))
print(ConfusionMatrixDisplay.from_predictions(y_test,y_testpred))
print('CR:',classification_report(y_test,y_testpred))
gbt=accuracy_score(y_test,y_testpred)*100
gbr=accuracy_score(y_train,y_trainpred)*100
print('Test accuracy:',gbt)
print('Train accuracy:',gbr)
# Out:
# Test accuracy: 0.8028814669286182
# train accuracy: 0.8250709761956759
# <sklearn.metrics._plot.confusion_matrix.ConfusionMatrixDisplay object at 0x0000017E2DA526D0>
# CR:               precision    recall  f1-score   support
#
#            0       0.76      0.89      0.82       757
#            1       0.87      0.72      0.79       770
#
#     accuracy                           0.80      1527
#    macro avg       0.81      0.80      0.80      1527
# weighted avg       0.81      0.80      0.80      1527
#
# Test accuracy: 80.28814669286182
# Train accuracy: 82.50709761956759

# %% [markdown]
# # PERFORMANCE AFTER SMOTE

# %%
tb=pd.DataFrame()
tb['model']=pd.Series(['knn','lr','gb','rf','adaboost','gbc','dt','xgb','sv'])
tb['test_accuracy']=pd.Series([knnt,lrt,gbt,rft,adt,gbt,dtt,xgt,svt])
tb['train_accuracy']=pd.Series([knnr,lrr,gbr,rfr,adr,gbr,dtr,xgr,svr])
tb
# Out:
#       model  test_accuracy  train_accuracy
# 0       knn      77.144728       86.285215
# 1        lr      63.261297       64.992356
# 2        gb      80.288147       82.507098
# 3        rf      79.698756       90.587465
# 4  adaboost      60.772757       60.974012
# 5       gbc      80.288147       82.507098
# 6        dt      80.877538       91.810439
# 7       xgb      81.204977       88.447259
# 8        sv      49.574329       50.141952

# %% [markdown]
# # HYPERPARAMETER TUNNING

# %%
from sklearn.model_selection import GridSearchCV
from xgboost import XGBClassifier
from sklearn.naive_bayes import MultinomialNB
from sklearn.ensemble import AdaBoostClassifier
from sklearn.ensemble import GradientBoostingClassifier

# %%
# RANDOM FOREST
# ------------------
rf_params={'n_estimators':[10,50,100],'max_depth':[2,4,6,None]}
rf_grid=GridSearchCV(RandomForestClassifier(random_state=42),rf_params,cv=5)
rf_grid.fit(x_train,y_train)
# Out:
# GridSearchCV(cv=5, estimator=RandomForestClassifier(random_state=42),
#              param_grid={'max_depth': [2, 4, 6, None],
#                          'n_estimators': [10, 50, 100]})

# %%
# SVM
# -------
svm_params={'C':[0.1,1,10],'kernel':['linear','rbf'],'gamma':['scale','auto']}
svm_grid=GridSearchCV(SVC(),svm_params,cv=5)
svm_grid.fit(x_train,y_train)
# Out:
# GridSearchCV(cv=5, estimator=SVC(),
#              param_grid={'C': [0.1, 1, 10], 'gamma': ['scale', 'auto'],
#                          'kernel': ['linear', 'rbf']})

# %%
# DECISION TREE
# ------------------
dt_params={'max_depth':[2,4,6,None],'criterion':['gini','entropy']}
dt_grid=GridSearchCV(DecisionTreeClassifier(random_state=42),dt_params,cv=5)
dt_grid.fit(x_train,y_train)
# Out:
# GridSearchCV(cv=5, estimator=DecisionTreeClassifier(random_state=42),
#              param_grid={'criterion': ['gini', 'entropy'],
#                          'max_depth': [2, 4, 6, None]})

# %%
# LOGITIC REGRESSION
# ----------------------
ir_params={'C':[0.1,1,10]}
ir_grid=GridSearchCV(LogisticRegression(),ir_params,cv=5)
ir_grid.fit(x_train,y_train)
# Out:
# GridSearchCV(cv=5, estimator=LogisticRegression(),
#              param_grid={'C': [0.1, 1, 10]})

# %%
# KNN
knn_param = {
    'n_neighbors':range(1, 31),  # Number of neighbors
    'weights':['uniform','distance'],  # Voting strategy
    'metric':['euclidean','manhattan','minkowski']  # Distance metric
}
knn_grid= GridSearchCV(knn,knn_param,cv=5,scoring='accuracy', n_jobs=-1)
knn_grid.fit(x_train,y_train)
# Out:
# GridSearchCV(cv=5, estimator=KNeighborsClassifier(n_neighbors=3), n_jobs=-1,
#              param_grid={'metric': ['euclidean', 'manhattan', 'minkowski'],
#                          'n_neighbors': range(1, 31),
#                          'weights': ['uniform', 'distance']},
#              scoring='accuracy')

# %%
#nb
nb_params={'alpha':[0.01,0.1,1,10]}
nb_grid=GridSearchCV(MultinomialNB(),nb_params,cv=3)
nb_grid.fit(x_train,y_train)
# Out:
# GridSearchCV(cv=3, estimator=MultinomialNB(),
#              param_grid={'alpha': [0.01, 0.1, 1, 10]})

# %%
#grb
gb_params = {
    'n_estimators': [50, 100, 150],
    'learning_rate': [0.01, 0.1, 0.2],
    'max_depth': [2, 3, 5]
}

gb_grid = GridSearchCV(GradientBoostingClassifier(), gb_params, cv=3)
gb_grid.fit(x_train, y_train)
# Out:
# GridSearchCV(cv=3, estimator=GradientBoostingClassifier(),
#              param_grid={'learning_rate': [0.01, 0.1, 0.2],
#                          'max_depth': [2, 3, 5],
#                          'n_estimators': [50, 100, 150]})

# %%
#ada
ada_params = {
    'n_estimators': [50, 100, 150],
    'learning_rate': [0.01, 0.1, 1]
}

ada_grid = GridSearchCV(AdaBoostClassifier(), ada_params, cv=3)
ada_grid.fit(x_train, y_train)
# Out:
# GridSearchCV(cv=3, estimator=AdaBoostClassifier(),
#              param_grid={'learning_rate': [0.01, 0.1, 1],
#                          'n_estimators': [50, 100, 150]})

# %%
# xgboost
xgb_params = {
    'n_estimators': [50, 100, 150],
    'learning_rate': [0.01, 0.1, 0.2],
    'max_depth': [3, 5, 7]
}

xgb_grid = GridSearchCV(XGBClassifier(), xgb_params, cv=3)
xgb_grid.fit(x_train, y_train)
# Out:
# GridSearchCV(cv=3,
#              estimator=XGBClassifier(base_score=None, booster=None,
#                                      callbacks=None, colsample_bylevel=None,
#                                      colsample_bynode=None,
#                                      colsample_bytree=None, device=None,
#                                      early_stopping_rounds=None,
#                                      enable_categorical=False, eval_metric=None,
#                                      feature_types=None, feature_weights=None,
#                                      gamma=None, grow_policy=None,
#                                      importance_type=None,
#                                      interaction_constraints=None,
#                                      learning_rate=None, max_bin=None,
#                                      max_cat_threshold=None,
#                                      max_cat_to_onehot=None,
#                                      max_delta_step=None, max_depth=None,
#                                      max_leaves=None, min_child_weight=None,
#                                      missing=nan, monotone_constraints=None,
#                                      multi_strategy=None, n_estimators=None,
#                                      n_jobs=None, num_parallel_tree=None, ...),
#              param_grid={'learning_rate': [0.01, 0.1, 0.2],
#                          'max_depth': [3, 5, 7],
#                          'n_estimators': [50, 100, 150]})

# %%
models = {'Random Forest': rf_grid,'SVM': svm_grid,'Logistic Regression': ir_grid,'Decision Tree': dt_grid,'KNN':knn_grid,'GB':gb_grid,'MultinomialNB':nb_grid,'AdaBoost':ada_grid,'XGBoost':xgb_grid}
for name, grid in models.items():
    best_model = grid.best_estimator_
    y_pred = best_model.predict(x_test)
    acc = accuracy_score(y_test, y_pred)
    print(f"{name}:")
    print(f"  Best Params: {grid.best_params_}")
    print(f"  Accuracy: {acc:.4f}\n")
# Out:
# Random Forest:
#   Best Params: {'max_depth': None, 'n_estimators': 100}
#   Accuracy: 0.8265
#
# SVM:
#   Best Params: {'C': 10, 'gamma': 'auto', 'kernel': 'rbf'}
#   Accuracy: 0.7990
#
# Logistic Regression:
#   Best Params: {'C': 10}
#   Accuracy: 0.6313
#
# Decision Tree:
#   Best Params: {'criterion': 'gini', 'max_depth': 6}
#   Accuracy: 0.8114
#
# KNN:
#   Best Params: {'metric': 'manhattan', 'n_neighbors': 24, 'weights': 'distance'}
#   Accuracy: 0.8055
#
# GB:
#   Best Params: {'learning_rate': 0.2, 'max_depth': 3, 'n_estimators': 150}
#   Accuracy: 0.8160
#
# MultinomialNB:
#   Best Params: {'alpha': 0.01}
#   Accuracy: 0.5972
#
# AdaBoost:
#   Best Params: {'learning_rate': 1, 'n_estimators': 100}
#   Accuracy: 0.7662
#
# XGBoost:
#   Best Params: {'learning_rate': 0.1, 'max_depth': 5, 'n_estimators': 150}
#   Accuracy: 0.8199

# %%
# Access the best model
best_rf_model = rf_grid.best_estimator_
y_pred = best_rf_model.predict(x_test)

# %%
print(best_rf_model)
# Out:
# RandomForestClassifier(random_state=42)

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split

# %%
import joblib
joblib.dump(rf,"Employee.pkl")
# Out:
# ['Employee.pkl']

# %%
joblib.dump(scaler,"scaler.pkl")
# Out:
# ['scaler.pkl']

# %%
joblib.dump(le,"le.pkl")
# Out:
# ['le.pkl']

# %%
joblib.dump(le1,"le1.pkl")
# Out:
# ['le1.pkl']

# %%
joblib.dump(le2,"le2.pkl")
# Out:
# ['le2.pkl']

# %%
joblib.dump(le3,"le3.pkl")
# Out:
# ['le3.pkl']
